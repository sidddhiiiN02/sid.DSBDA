# %% [markdown]
# Assignment no.8
# Name: Siddhi Narke
# TE-B3 Batch 13267

# %%
import matplotlib.pyplot as plt

# %%
pt=[23,26,34,38,43,56]
plt.plot(pt)
plt.show()

# %%
plt.plot(pt)
plt.xlabel("sample point")
plt.ylabel("values")
plt.title("point vs value")
# Out:
# Text(0.5, 1.0, 'point vs value')

# %%
pt1=[78,34,56,67,27,87,45,33]
plt.plot(pt)
plt.plot(pt1)

# %%
plt.plot(pt , c='b' , marker='o' , mec='r' )
plt.plot(pt1 , c='r', marker='*',mec='b')
plt.xlabel("sample point")
plt.ylabel("values")
plt.title("point vs value")
# Out:
# Text(0.5, 1.0, 'point vs value')

# %%
plt.plot(pt , c='b' , marker='o' , mec='r', ls=':')
plt.plot(pt1 , c='r', marker='*',mec='b', ls=':')
plt.xlabel("sample point")
plt.ylabel("values")
plt.title("point vs value")
# Out:
# Text(0.5, 1.0, 'point vs value')

# %%
plt.plot(pt , c='b' , marker='o' , mec='r', dash_capstyle ='round')
plt.plot(pt1 , c='r', marker='*',mec='b', ls=':')
plt.xlabel("sample point")
plt.ylabel("values")
plt.title("point vs value")
# Out:
# Text(0.5, 1.0, 'point vs value')

# %%
plt.plot(pt , c='b' , marker='o' , mec='r', dash_capstyle ='round')
plt.plot(pt1 , c='r', marker='*',mec='b', ls=':')
plt.xlabel("sample point")
plt.ylabel("values")
plt.title("point vs value")
plt.legend(['cns','dbms'])
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=sns.load_dataset('titanic')

# %%
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 1.DISTRIBUTION :
# Distplot

# %%
sns.distplot(x = dataset['age'],bins = 10)
# Out:
# C:\Users\Siddhi\AppData\Local\Temp\ipykernel_35044\2360769725.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = dataset['age'],bins = 10)
# <Axes: ylabel='Density'>

# %%
sns.distplot(dataset['age'], bins = 10,kde=False)
# Out:
# C:\Users\Siddhi\AppData\Local\Temp\ipykernel_35044\3517108427.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['age'], bins = 10,kde=False)
# <Axes: xlabel='age'>

# %%
sns.jointplot(x = dataset['age'], y = dataset['fare'], kind ='scatter')

# %% [markdown]
# Joint Plot:

# %%
sns.jointplot(x = dataset['age'], y = dataset['fare'], kind = 'hex')

# %% [markdown]
# Rug Plot

# %%
sns.rugplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare'>

# %% [markdown]
# 2.CATEGORICAL :
# Bar Plot

# %%
sns.barplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='sex', y='age', data=dataset, estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# Count Plot

# %%
sns.countplot(x='sex', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex', y='age', data=dataset, hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# Violin Plot

# %%
sns.violinplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex', y='age', data=dataset, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# 3.ADVANCED PLOTS:
# Strip Plots:

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=True, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# Swarm Plot:

# %%
sns.swarmplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex', y='age', data=dataset, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# 4.MATRIX PLOTS:
# Heat map:

# %%
corr=dataset.corr(numeric_only=True)
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
corr = dataset.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()

# %%
corr=dataset.corr(numeric_only=True)
sns.heatmap(corr,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Cluster Map:

# %%
sns.histplot(dataset['fare'], kde=False, bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
