# %%
import nltk

# %%
import re

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Siddhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Siddhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Siddhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Siddhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = """Tokenization is the first step in text analytics.
The process of breaking down a text paragraph into smaller chunks such as words or sentences is called tokenization."""

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Siddhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# Tokenization:
# 1.Sentence tokenization

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Tokenization is the first step in text analytics.', 'The process of breaking down a text paragraph into smaller chunks such as words or sentences is called tokenization.']

# %% [markdown]
# 2.Word tokenization

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(text)
print(words)
# Out:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'tokenization', '.']

# %% [markdown]
# 3.Remove punctuations and stopwords

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'will', 'just', 'in', 'no', 'of', 'once', 'any', 'his', 'how', "she'd", "hasn't", "isn't", "i'll", 'yourselves', 'out', 'did', 'i', "doesn't", 'or', 'don', 'again', 'about', 'at', 'some', 'up', 'not', 'below', 'wouldn', 've', 'other', 'when', "she's", 'this', 'before', 'been', 'ours', "we've", 'both', 'had', 'herself', 'too', 'himself', 'into', 'll', 'through', 'y', "they've", 'their', 'here', 'that', 'whom', 'wasn', 'ain', "aren't", 'on', 'does', 'above', 'needn', 'weren', "haven't", 'only', "you'd", 'your', 'yours', 'theirs', 'now', 'aren', "couldn't", 'ourselves', 'more', 'myself', 'under', 'until', "they'd", "shan't", "they'll", 'isn', 'very', 'but', 'those', 'few', 'an', 'be', 'its', "he's", 'my', 'where', 'couldn', 'down', 'a', "shouldn't", 'with', "you've", 'was', 'it', 'over', 'by', 'didn', 'has', 'off', 'because', 'have', 'themselves', "wasn't", 'haven', "should've", "that'll", 'do', 'shouldn', 'so', 'are', 'he', 'd', "i'm", "they're", 'yourself', 'hadn', "needn't", 'mightn', 'against', 'and', 'as', 'while', 'most', 'why', 'after', "i'd", 'mustn', 'between', 'won', 'her', 'were', 'further', "he'd", 'having', 'shan', 'each', "don't", 'them', 'nor', "you're", 'being', 'doing', "he'll", "she'll", 'such', 'they', "it'll", "hadn't", 'she', 'who', 'all', 'ma', "we'll", "we're", 'hasn', 'should', 'him', 'which', 'during', 'hers', 'doesn', "wouldn't", "it'd", 'o', "weren't", 'then', 't', "won't", 're', 'to', "i've", 'is', 'than', 'own', 'we', 'same', 'm', "you'll", "it's", 'if', 'can', "didn't", 'from', 'me', 's', "mustn't", 'for', "we'd", 'what', 'itself', 'our', "mightn't", 'am', 'there', 'these', 'you', 'the'}

# %%
text= re.sub('[^a-zA-Z]', ' ',text)
tokens = word_tokenize(text.lower())
filtered_text = []
for w in tokens:
    if w not in stop_words:
     filtered_text.append(w)
print ("tokenized wods:" , tokens)
print("filtered text:" , filtered_text)
# Out:
# tokenized wods: ['tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', 'the', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'tokenization']
# filtered text: ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunks', 'words', 'sentences', 'called', 'tokenization']

# %% [markdown]
# 4.Stemming

# %%
from nltk.stem import PorterStemmer
e_words= ["wait" ,"waited" ,"waiting" ,"waits"]
ps=PorterStemmer()
for w in e_words:
    rootWord=ps.stem(w)
print(rootWord)
# Out:
# wait

# %% [markdown]
# 5.lemmatization

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
text="studies studying cries cry"
tokenization=nltk.word_tokenize(text)
for w in tokenization:
    print("Lemma  for  {}  is  {}".format(w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma  for  studies  is  study
# Lemma  for  studying  is  studying
# Lemma  for  cries  is  cry
# Lemma  for  cry  is  cry

# %% [markdown]
# 6.POS tagging to text

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Siddhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Siddhi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk

pos = nltk.pos_tag(words)

print(pos)
# Out:
# [('Tokenization', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('first', 'JJ'), ('step', 'NN'), ('in', 'IN'), ('text', 'JJ'), ('analytics', 'NNS'), ('.', '.'), ('The', 'DT'), ('process', 'NN'), ('of', 'IN'), ('breaking', 'VBG'), ('down', 'RP'), ('a', 'DT'), ('text', 'NN'), ('paragraph', 'NN'), ('into', 'IN'), ('smaller', 'JJR'), ('chunks', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('words', 'NNS'), ('or', 'CC'), ('sentences', 'NNS'), ('is', 'VBZ'), ('called', 'VBN'), ('tokenization', 'NN'), ('.', '.')]
