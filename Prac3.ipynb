# %%
import numpy as np
import pandas as pd
from scipy.stats import skew
import seaborn as sns

# %%
data = pd.read_csv(r"C:/Users/mestr/Downloads/Salary Data.csv")

# %%
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# Age                        37.431635
# Years of Experience        10.030831
# Salary                 100577.345845
# dtype: float64

# %%
df.mode()
# Out:
#     Age Gender Education Level              Job Title  Years of Experience  \
# 0  33.0   Male      Bachelor's  Director of Marketing                  2.0
#
#     Salary
# 0  40000.0

# %%
df.median(numeric_only=True)
# Out:
# Age                       36.0
# Years of Experience        9.0
# Salary                 95000.0
# dtype: float64

# %%
df.loc[:,'Age'].mode()
# Out:
# 0    33.0
# Name: Age, dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# Age                     23.0
# Years of Experience      0.0
# Salary                 350.0
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# Age                        53.0
# Years of Experience        25.0
# Salary                 250000.0
# dtype: float64

# %%
df.loc[:,'Age'].max(skipna = False)
# Out:
# np.float64(nan)

# %%
df.std(numeric_only=True)
# Out:
# Age                        7.069073
# Years of Experience        6.557007
# Salary                 48240.013482
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# Age                    0.197522
# Years of Experience    0.361220
# Salary                 0.400578
# dtype: float64

# %%
import matplotlib.pyplot as plt

df['Salary'].hist(bins=10)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %%
df.groupby(['Gender'])['Age'].mean(numeric_only=True)
# Out:
# Gender
# Female    37.581006
# Male      37.293814
# Name: Age, dtype: float64

# %%
df_u=df.rename(columns= {'Education Level k$)':'Salary'},inplace=False)

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df[["Age","Years of Experience","Salary"]].mean(axis=1)[0:4]
# Out:
# 0    30012.333333
# 1    21677.000000
# 2    50020.000000
# 3    20014.333333
# dtype: float64

# %%
df.mode()
# Out:
#     Age Gender Education Level              Job Title  Years of Experience  \
# 0  33.0   Male      Bachelor's  Director of Marketing                  2.0
#
#     Salary
# 0  40000.0

# %%
df.loc[:,'Age'].mode()
# Out:
# 0    33.0
# Name: Age, dtype: float64

# %%
df.loc[:,'Age'].min(skipna = False)
# Out:
# np.float64(nan)

# %%
df.boxplot(column=['Age','Years of Experience','Salary'])
plt.title("Boxplot of Salary Dataset")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Age'], df['Salary'], marker='.')
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()

# %%
(df['Salary'] > 50000).sum()
# Out:
# np.int64(287)

# %%
skewness=(3*(mean-median))/df
print(f"Skewness={skewness}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 skewness=(3*(mean-median))/df
#       2 print(f"Skewness={skewness}")
#
# NameError: name 'mean' is not defined

# %%
df['Salary'].skew()
# Out:
# np.float64(0.400578053273342)

# %%
mean = df['Salary'].mean()
median = df['Salary'].median()

# %%
sns.kdeplot(df['Salary'])
plt.axvline(mean, label="Mean")
plt.axvline(median, color="red", label="Median")

plt.legend()
plt.show()

# %%
sns.histplot(df["Salary"], kde=True)
plt.title("Skewness Graph of Salary")
plt.show()

# %%
sns.histplot(df["Age"], kde=True)
plt.title("Skewness Graph of Age")
plt.show()

# %%
sns.histplot(df["Years of Experience"], kde=True)
plt.title("Skewness Graph of Years of Experience")
plt.show()
