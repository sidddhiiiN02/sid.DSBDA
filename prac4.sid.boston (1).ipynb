# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data =pd.read_csv("C:/Users/Siddhi/Downloads/boston prac4 dataset/boston.csv")

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data= data.drop(["CHAS"],axis=1)

# %%
data = data.drop(["ZN"],axis=1)

# %%
data
# Out:
#         CRIM  INDUS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO       B  \
# 0    0.00632   2.31  0.538  6.575  65.2  4.0900    1  296.0     15.3  396.90
# 1    0.02731   7.07  0.469  6.421  78.9  4.9671    2  242.0     17.8  396.90
# 2    0.02729   7.07  0.469  7.185  61.1  4.9671    2  242.0     17.8  392.83
# 3    0.03237   2.18  0.458  6.998  45.8  6.0622    3  222.0     18.7  394.63
# 4    0.06905   2.18  0.458  7.147  54.2  6.0622    3  222.0     18.7  396.90
# ..       ...    ...    ...    ...   ...     ...  ...    ...      ...     ...
# 501  0.06263  11.93  0.573  6.593  69.1  2.4786    1  273.0     21.0  391.99
# 502  0.04527  11.93  0.573  6.120  76.7  2.2875    1  273.0     21.0  396.90
# 503  0.06076  11.93  0.573  6.976  91.0  2.1675    1  273.0     21.0  396.90
# 504  0.10959  11.93  0.573  6.794  89.3  2.3889    1  273.0     21.0  393.45
# 505  0.04741  11.93  0.573  6.030  80.8  2.5050    1  273.0     21.0  396.90
#
#      LSTAT  MEDV
# 0     4.98  24.0
# ...

# %%
X = data.drop("MEDV", axis=1)
y = data["MEDV"]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split( X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ytrain_pred = model.predict(xtrain)
ytest_pred = model.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("Training MSE:", mean_squared_error(ytrain, ytrain_pred))
print("Testing MSE:", mean_squared_error(ytest, ytest_pred))
print("Training R2:", r2_score(ytrain, ytrain_pred))
print("Testing R2:", r2_score(ytest, ytest_pred))
# Out:
# Training MSE: 20.138643787113732
# Testing MSE: 35.01170873305257
# Training R2: 0.7634747021360054
# Testing R2: 0.570030948199341

# %%
plt.figure(figsize=(8,6))
plt.scatter(ytrain, ytrain_pred, c='blue', marker='o', label='Training data')
plt.scatter(ytest, ytest_pred, c='lightgreen', marker='s', label='Test data')
plt.plot([0, 50], [0, 50], 'r--')
plt.xlabel("Actual MEDV")
plt.ylabel("Predicted MEDV")
plt.title("Linear Regression Model Performance")
plt.legend(loc='upper left')
plt.show()

# %%
plt.scatter(ytrain ,ytrain_pred,c='pink',marker='o',label='Training data')
plt.scatter(ytest,ytest_pred ,c='grey',marker='s',label='Test data')
plt.xlabel('True values')
plt.ylabel('Predicted')
plt.title("True value vs Predicted value")
plt.legend(loc='upper left')
plt.plot()
plt.show()
